# %%
import os
import cv2
import yaml
import torch
import numpy as np
import pandas as pd
from  torch import nn
import mediapipe as mp
from torch import optim
from datetime import datetime
from torchmetrics import Accuracy
from torch.utils.data import Dataset

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        list_label = label_dict_from_config_file("hand_gesture.yaml")
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(63, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.6),
            nn.Linear(128, len(list_label)),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

    def predict(self,x,threshold=0.8):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        chosen_ind = torch.argmax(softmax_prob,dim=1)
        return torch.where(softmax_prob[0,chosen_ind]>threshold,chosen_ind,-1)

    def predict_with_known_class(self,x):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        return torch.argmax(softmax_prob,dim=1)

    def score(self,logits):
        return -torch.amax(logits,dim=1)

# %%
def label_dict_from_config_file(relative_path):
    with open(relative_path,"r") as f:
       label_tag = yaml.full_load(f)["gestures"]
    return label_tag

# %%
class HandLandmarksDetector():
    def __init__(self) -> None:
        self.mp_drawing = mp.solutions.drawing_utils
        self.mp_drawing_styles = mp.solutions.drawing_styles
        self.mp_hands = mp.solutions.hands
        self.detector = self.mp_hands.Hands(False,max_num_hands=1,min_detection_confidence=0.5)

    def detectHand(self,frame):
        hands = []
        frame = cv2.flip(frame, 1)
        annotated_image = frame.copy()
        results = self.detector.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        if results.multi_hand_landmarks is not None:
            for hand_landmarks in results.multi_hand_landmarks:
                hand = []
                self.mp_drawing.draw_landmarks(
                    annotated_image,
                    hand_landmarks,
                    self.mp_hands.HAND_CONNECTIONS,
                    self.mp_drawing_styles.get_default_hand_landmarks_style(),
                    self.mp_drawing_styles.get_default_hand_connections_style())
                for landmark in hand_landmarks.landmark:
                    x,y,z = landmark.x,landmark.y,landmark.z
                    hand.extend([x,y,z])
            hands.append(hand)
        return hands,annotated_image

# %%
class CustomImageDataset(Dataset):
    def __init__(self, data_file):
        self.data = pd.read_csv(data_file)
        self.labels = torch.from_numpy(self.data.iloc[:,0].to_numpy())

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        one_hot_label = self.labels[idx]
        torch_data = torch.from_numpy(self.data.iloc[idx,1:].to_numpy(dtype=np.float32))
        return torch_data, one_hot_label

# %%
class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.watched_metrics = np.inf

    def early_stop(self, current_value):
        if current_value < self.watched_metrics:
            self.watched_metrics = current_value
            self.counter = 0
        elif current_value > (self.watched_metrics + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
def train(trainloader, val_loader, model, loss_function, early_stopper, optimizer):
    # add auroc score
    best_vloss = 1_000_000
    # timestamp = datetime.now().strftime('%d-%m %H:%M')
    timestamp = datetime.now().strftime('%d-%m_%H-%M')
    for epoch in range(300):
        #training step
        model.train(True)
        running_loss = 0.0
        acc_train = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for batch_number,data in enumerate(trainloader):
            inputs,labels = data
            optimizer.zero_grad()
            preds = model(inputs)
            loss = loss_function(preds,labels)
            loss.backward()
            optimizer.step()
            acc_train.update(model.predict_with_known_class(inputs), labels)
            running_loss += loss.item()
        avg_loss = running_loss / len(trainloader)
        # validating step
        model.train(False)
        running_vloss = 0.0
        acc_val = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for i, vdata in enumerate(val_loader):
            vinputs, vlabels = vdata
            preds = model(vinputs)
            vloss = loss_function(preds, vlabels)
            running_vloss += vloss.item()
            acc_val.update(model.predict_with_known_class(vinputs), vlabels)

        # Log the running loss averaged per batch
        # for both training and validation
        print(f"Epoch {epoch}: ")
        print(f"Accuracy train:{acc_train.compute().item()}, val:{acc_val.compute().item()}")
        avg_vloss = running_vloss / len(val_loader)
        print('LOSS train {} valid {}'.format(avg_loss, avg_vloss))
        print('Training vs. Validation Loss',
                        { 'Training' : avg_loss, 'Validation' : avg_vloss },
                        epoch + 1)
        print('Training vs. Validation accuracy',
                        { 'Training' : acc_train.compute().item()
                        , 'Validation' : acc_val.compute().item() },
                        epoch + 1)

        # Track best performance, and save the model's state
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            # best_model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_best'
            best_model_path = os.path.join(save_path, f'model_{timestamp}_{model.__class__.__name__}_best.pth')
            torch.save(model.state_dict(), best_model_path)
        if early_stopper.early_stop(avg_vloss):
            print(f"stopping at epoch {epoch}, minimum: {early_stopper.watched_metrics}")
            break

    # model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_last'
    model_path = os.path.join(save_path, f'model_{timestamp}_{model.__class__.__name__}_last.pth')
    torch.save(model.state_dict(), model_path)

    print(acc_val.compute())
    return model, best_model_path

# %%
DATA_FOLDER_PATH="./data/"
LIST_LABEL = label_dict_from_config_file("hand_gesture.yaml")
train_path = os.path.join(DATA_FOLDER_PATH,"landmark_train.csv")
val_path = os.path.join(DATA_FOLDER_PATH,"landmark_val.csv")
save_path = './models'
os.makedirs(save_path,exist_ok=True)

trainset = CustomImageDataset(train_path)
trainloader = torch.utils.data.DataLoader(trainset,batch_size=40,shuffle=True)

valset = CustomImageDataset(os.path.join(val_path))
val_loader = torch.utils.data.DataLoader(valset,batch_size=50, shuffle=False)

model = NeuralNetwork()
loss_function = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience=30,min_delta=0.01)
optimizer = optim.Adam(model.parameters(),lr=0.0001)

model, best_model_path = train(trainloader, val_loader, model, loss_function, early_stopper, optimizer)
# Out:
# Epoch 0:
# Accuracy train:0.42833495140075684, val:0.6496350169181824
# LOSS train 1.4897020570524446 valid 1.2603524327278137
# Training vs. Validation Loss {'Training': 1.4897020570524446, 'Validation': 1.2603524327278137} 1
# Training vs. Validation accuracy {'Training': 0.42833495140075684, 'Validation': 0.6496350169181824} 1
# Epoch 1:
# Accuracy train:0.6955441832542419, val:0.9406934380531311
# LOSS train 0.8321825840643474 valid 0.5767860537267883
# Training vs. Validation Loss {'Training': 0.8321825840643474, 'Validation': 0.5767860537267883} 2
# Training vs. Validation accuracy {'Training': 0.6955441832542419, 'Validation': 0.9406934380531311} 2
# Epoch 2:
# Accuracy train:0.9198510050773621, val:0.8549270033836365
# LOSS train 0.34957642935134553 valid 0.2805504268379247
# Training vs. Validation Loss {'Training': 0.34957642935134553, 'Validation': 0.2805504268379247} 3
# Training vs. Validation accuracy {'Training': 0.9198510050773621, 'Validation': 0.8549270033836365} 3
# Epoch 3:
# Accuracy train:0.9564077854156494, val:0.831204354763031
# LOSS train 0.17314889924703064 valid 0.3646020940739783
# Training vs. Validation Loss {'Training': 0.17314889924703064, 'Validation': 0.3646020940739783} 4
# Training vs. Validation accuracy {'Training': 0.9564077854156494, 'Validation': 0.831204354763031} 4
# Epoch 4:
# Accuracy train:0.9667540192604065, val:0.8631386756896973
# LOSS train 0.12640798540663098 valid 0.24303116134342417
# Training vs. Validation Loss {'Training': 0.12640798540663098, 'Validation': 0.24303116134342417} 5
# Training vs. Validation accuracy {'Training': 0.9667540192604065, 'Validation': 0.8631386756896973} 5
# Epoch 5:
# Accuracy train:0.9739274382591248, val:0.82025545835495
# LOSS train 0.10675691178703046 valid 0.5900908680738336
# Training vs. Validation Loss {'Training': 0.10675691178703046, 'Validation': 0.5900908680738336} 6
# Training vs. Validation accuracy {'Training': 0.9739274382591248, 'Validation': 0.82025545835495} 6
# Epoch 6:
# Accuracy train:0.9780659675598145, val:0.8822992444038391
# LOSS train 0.08773401869553049 valid 0.28040909432460964
# Training vs. Validation Loss {'Training': 0.08773401869553049, 'Validation': 0.28040909432460964} 7
# Training vs. Validation accuracy {'Training': 0.9780659675598145, 'Validation': 0.8822992444038391} 7
# Epoch 7:
# Accuracy train:0.9802731275558472, val:0.9142335653305054
# LOSS train 0.07609808763775688 valid 0.2577835010099689
# Training vs. Validation Loss {'Training': 0.07609808763775688, 'Validation': 0.2577835010099689} 8
# Training vs. Validation accuracy {'Training': 0.9802731275558472, 'Validation': 0.9142335653305054} 8
# Epoch 8:
# Accuracy train:0.9819285273551941, val:0.9479926824569702
# LOSS train 0.07073276603573954 valid 0.18455447805119587
# Training vs. Validation Loss {'Training': 0.07073276603573954, 'Validation': 0.18455447805119587} 9
# Training vs. Validation accuracy {'Training': 0.9819285273551941, 'Validation': 0.9479926824569702} 9
# Epoch 9:
# Accuracy train:0.9780659675598145, val:0.9288321137428284
# LOSS train 0.0736627786594269 valid 0.2630407367990777
# Training vs. Validation Loss {'Training': 0.0736627786594269, 'Validation': 0.2630407367990777} 10
# Training vs. Validation accuracy {'Training': 0.9780659675598145, 'Validation': 0.9288321137428284} 10
# Epoch 10:
# Accuracy train:0.9823423624038696, val:0.8485401272773743
# LOSS train 0.06345806825281745 valid 0.54382146288705
# Training vs. Validation Loss {'Training': 0.06345806825281745, 'Validation': 0.54382146288705} 11
# Training vs. Validation accuracy {'Training': 0.9823423624038696, 'Validation': 0.8485401272773743} 11
# Epoch 11:
# Accuracy train:0.9838598370552063, val:0.8959854245185852
# LOSS train 0.06426447825659844 valid 0.34585622150209683
# Training vs. Validation Loss {'Training': 0.06426447825659844, 'Validation': 0.34585622150209683} 12
# Training vs. Validation accuracy {'Training': 0.9838598370552063, 'Validation': 0.8959854245185852} 12
# Epoch 12:
# Accuracy train:0.9852393269538879, val:0.8722627758979797
# LOSS train 0.057242869084782814 valid 0.4366966911681981
# Training vs. Validation Loss {'Training': 0.057242869084782814, 'Validation': 0.4366966911681981} 13
# Training vs. Validation accuracy {'Training': 0.9852393269538879, 'Validation': 0.8722627758979797} 13
# Epoch 13:
# Accuracy train:0.986204981803894, val:0.9507299065589905
# LOSS train 0.052892137839520285 valid 0.17653554912030503
# Training vs. Validation Loss {'Training': 0.052892137839520285, 'Validation': 0.17653554912030503} 14
# Training vs. Validation accuracy {'Training': 0.986204981803894, 'Validation': 0.9507299065589905} 14
# Epoch 14:
# Accuracy train:0.9842736721038818, val:0.9479926824569702
# LOSS train 0.048491223862363986 valid 0.22357523698893964
# Training vs. Validation Loss {'Training': 0.048491223862363986, 'Validation': 0.22357523698893964} 15
# Training vs. Validation accuracy {'Training': 0.9842736721038818, 'Validation': 0.9479926824569702} 15
# Epoch 15:
# Accuracy train:0.9886881113052368, val:0.9425182342529297
# LOSS train 0.044553326337935996 valid 0.24329069531705985
# Training vs. Validation Loss {'Training': 0.044553326337935996, 'Validation': 0.24329069531705985} 16
# Training vs. Validation accuracy {'Training': 0.9886881113052368, 'Validation': 0.9425182342529297} 16
# Epoch 16:
# Accuracy train:0.9875844717025757, val:0.9516423344612122
# LOSS train 0.04562684684316372 valid 0.19404493132682757
# Training vs. Validation Loss {'Training': 0.04562684684316372, 'Validation': 0.19404493132682757} 17
# Training vs. Validation accuracy {'Training': 0.9875844717025757, 'Validation': 0.9516423344612122} 17
# Epoch 17:
# Accuracy train:0.9864808917045593, val:0.9498175382614136
# LOSS train 0.04985144106827288 valid 0.2016353698971394
# Training vs. Validation Loss {'Training': 0.04985144106827288, 'Validation': 0.2016353698971394} 18
# Training vs. Validation accuracy {'Training': 0.9864808917045593, 'Validation': 0.9498175382614136} 18
# Epoch 18:
# Accuracy train:0.987860381603241, val:0.9507299065589905
# LOSS train 0.045324051672091276 valid 0.20016605321094066
# Training vs. Validation Loss {'Training': 0.045324051672091276, 'Validation': 0.20016605321094066} 19
# Training vs. Validation accuracy {'Training': 0.987860381603241, 'Validation': 0.9507299065589905} 19
# Epoch 19:
# Accuracy train:0.9886881113052368, val:0.9425182342529297
# LOSS train 0.04180742642755241 valid 0.25202997742943595
# Training vs. Validation Loss {'Training': 0.04180742642755241, 'Validation': 0.25202997742943595} 20
# Training vs. Validation accuracy {'Training': 0.9886881113052368, 'Validation': 0.9425182342529297} 20
# Epoch 20:
# Accuracy train:0.9897916913032532, val:0.9616788029670715
# LOSS train 0.04183246526972053 valid 0.12892591662939878
# Training vs. Validation Loss {'Training': 0.04183246526972053, 'Validation': 0.12892591662939878} 21
# Training vs. Validation accuracy {'Training': 0.9897916913032532, 'Validation': 0.9616788029670715} 21
# Epoch 21:
# Accuracy train:0.9877224564552307, val:0.9826642274856567
# LOSS train 0.04101926563461158 valid 0.043684571909795716
# Training vs. Validation Loss {'Training': 0.04101926563461158, 'Validation': 0.043684571909795716} 22
# Training vs. Validation accuracy {'Training': 0.9877224564552307, 'Validation': 0.9826642274856567} 22
# Epoch 22:
# Accuracy train:0.9903435111045837, val:0.9653284549713135
# LOSS train 0.04105721551229011 valid 0.15522950878059885
# Training vs. Validation Loss {'Training': 0.04105721551229011, 'Validation': 0.15522950878059885} 23
# Training vs. Validation accuracy {'Training': 0.9903435111045837, 'Validation': 0.9653284549713135} 23
# Epoch 23:
# Accuracy train:0.9889640212059021, val:0.9698905348777771
# LOSS train 0.03710784851880437 valid 0.10293859354993887
# Training vs. Validation Loss {'Training': 0.03710784851880437, 'Validation': 0.10293859354993887} 24
# Training vs. Validation accuracy {'Training': 0.9889640212059021, 'Validation': 0.9698905348777771} 24
# Epoch 24:
# Accuracy train:0.9902055263519287, val:0.9616788029670715
# LOSS train 0.03634806394424791 valid 0.17138334222663268
# Training vs. Validation Loss {'Training': 0.03634806394424791, 'Validation': 0.17138334222663268} 25
# Training vs. Validation accuracy {'Training': 0.9902055263519287, 'Validation': 0.9616788029670715} 25
# Epoch 25:
# Accuracy train:0.9899296164512634, val:0.9644160866737366
# LOSS train 0.03700832225117515 valid 0.1528848532481552
# Training vs. Validation Loss {'Training': 0.03700832225117515, 'Validation': 0.1528848532481552} 26
# Training vs. Validation accuracy {'Training': 0.9899296164512634, 'Validation': 0.9644160866737366} 26
# Epoch 26:
# Accuracy train:0.9911711812019348, val:0.9571167826652527
# LOSS train 0.03741249727382028 valid 0.2113028980507714
# Training vs. Validation Loss {'Training': 0.03741249727382028, 'Validation': 0.2113028980507714} 27
# Training vs. Validation accuracy {'Training': 0.9911711812019348, 'Validation': 0.9571167826652527} 27
# Epoch 27:
# Accuracy train:0.990481436252594, val:0.9762773513793945
# LOSS train 0.03745581137443698 valid 0.05815707942558939
# Training vs. Validation Loss {'Training': 0.03745581137443698, 'Validation': 0.05815707942558939} 28
# Training vs. Validation accuracy {'Training': 0.990481436252594, 'Validation': 0.9762773513793945} 28
# Epoch 28:
# Accuracy train:0.9915850758552551, val:0.9653284549713135
# LOSS train 0.03337202318892865 valid 0.11454787088162922
# Training vs. Validation Loss {'Training': 0.03337202318892865, 'Validation': 0.11454787088162922} 29
# Training vs. Validation accuracy {'Training': 0.9915850758552551, 'Validation': 0.9653284549713135} 29
# Epoch 29:
# Accuracy train:0.990619421005249, val:0.9461678862571716
# LOSS train 0.03135363102166473 valid 0.24584937096368167
# Training vs. Validation Loss {'Training': 0.03135363102166473, 'Validation': 0.24584937096368167} 30
# Training vs. Validation accuracy {'Training': 0.990619421005249, 'Validation': 0.9461678862571716} 30
# Epoch 30:
# Accuracy train:0.9895157814025879, val:0.959854006767273
# LOSS train 0.038037494874615635 valid 0.1822712467903167
# Training vs. Validation Loss {'Training': 0.038037494874615635, 'Validation': 0.1822712467903167} 31
# Training vs. Validation accuracy {'Training': 0.9895157814025879, 'Validation': 0.959854006767273} 31
# Epoch 31:
# Accuracy train:0.9913091659545898, val:0.9498175382614136
# LOSS train 0.03604431008164653 valid 0.2298786790005539
# Training vs. Validation Loss {'Training': 0.03604431008164653, 'Validation': 0.2298786790005539} 32
# Training vs. Validation accuracy {'Training': 0.9913091659545898, 'Validation': 0.9498175382614136} 32
# Epoch 32:
# Accuracy train:0.9911711812019348, val:0.9589415788650513
# LOSS train 0.03106652665643436 valid 0.2069311157703403
# Training vs. Validation Loss {'Training': 0.03106652665643436, 'Validation': 0.2069311157703403} 33
# Training vs. Validation accuracy {'Training': 0.9911711812019348, 'Validation': 0.9589415788650513} 33
# Epoch 33:
# Accuracy train:0.992274820804596, val:0.9279196858406067
# LOSS train 0.029535305990765873 valid 0.23642364934732285
# Training vs. Validation Loss {'Training': 0.029535305990765873, 'Validation': 0.23642364934732285} 34
# Training vs. Validation accuracy {'Training': 0.992274820804596, 'Validation': 0.9279196858406067} 34
# Epoch 34:
# Accuracy train:0.9914470911026001, val:0.9625912308692932
# LOSS train 0.03483437734354124 valid 0.18649446553529003
# Training vs. Validation Loss {'Training': 0.03483437734354124, 'Validation': 0.18649446553529003} 35
# Training vs. Validation accuracy {'Training': 0.9914470911026001, 'Validation': 0.9625912308692932} 35
# Epoch 35:
# Accuracy train:0.9914470911026001, val:0.9653284549713135
# LOSS train 0.026684371045960758 valid 0.15376699762822066
# Training vs. Validation Loss {'Training': 0.026684371045960758, 'Validation': 0.15376699762822066} 36
# Training vs. Validation accuracy {'Training': 0.9914470911026001, 'Validation': 0.9653284549713135} 36
# Epoch 36:
# Accuracy train:0.993240475654602, val:0.9635036587715149
# LOSS train 0.02944110486698644 valid 0.14560490650584604
# Training vs. Validation Loss {'Training': 0.02944110486698644, 'Validation': 0.14560490650584604} 37
# Training vs. Validation accuracy {'Training': 0.993240475654602, 'Validation': 0.9635036587715149} 37
# Epoch 37:
# Accuracy train:0.9918609261512756, val:0.9571167826652527
# LOSS train 0.031384115139499645 valid 0.14982253242239646
# Training vs. Validation Loss {'Training': 0.031384115139499645, 'Validation': 0.14982253242239646} 38
# Training vs. Validation accuracy {'Training': 0.9918609261512756, 'Validation': 0.9571167826652527} 38
# Epoch 38:
# Accuracy train:0.9924127459526062, val:0.930656909942627
# LOSS train 0.02564641188927363 valid 0.34032681818103894
# Training vs. Validation Loss {'Training': 0.02564641188927363, 'Validation': 0.34032681818103894} 39
# Training vs. Validation accuracy {'Training': 0.9924127459526062, 'Validation': 0.930656909942627} 39
# Epoch 39:
# Accuracy train:0.9918609261512756, val:0.9689781069755554
# LOSS train 0.022164758498227775 valid 0.14070528926446615
# Training vs. Validation Loss {'Training': 0.022164758498227775, 'Validation': 0.14070528926446615} 40
# Training vs. Validation accuracy {'Training': 0.9918609261512756, 'Validation': 0.9689781069755554} 40
# Epoch 40:
# Accuracy train:0.9933784008026123, val:0.9616788029670715
# LOSS train 0.027363388197225325 valid 0.16992990047164805
# Training vs. Validation Loss {'Training': 0.027363388197225325, 'Validation': 0.16992990047164805} 41
# Training vs. Validation accuracy {'Training': 0.9933784008026123, 'Validation': 0.9616788029670715} 41
# Epoch 41:
# Accuracy train:0.9939302206039429, val:0.9680656790733337
# LOSS train 0.022543362959158212 valid 0.13016968503400506
# Training vs. Validation Loss {'Training': 0.022543362959158212, 'Validation': 0.13016968503400506} 42
# Training vs. Validation accuracy {'Training': 0.9939302206039429, 'Validation': 0.9680656790733337} 42
# Epoch 42:
# Accuracy train:0.994895875453949, val:0.9698905348777771
# LOSS train 0.020339912711898542 valid 0.10861179549731564
# Training vs. Validation Loss {'Training': 0.020339912711898542, 'Validation': 0.10861179549731564} 43
# Training vs. Validation accuracy {'Training': 0.994895875453949, 'Validation': 0.9698905348777771} 43
# Epoch 43:
# Accuracy train:0.9925506711006165, val:0.9607664346694946
# LOSS train 0.025825829040463807 valid 0.1708254633422271
# Training vs. Validation Loss {'Training': 0.025825829040463807, 'Validation': 0.1708254633422271} 44
# Training vs. Validation accuracy {'Training': 0.9925506711006165, 'Validation': 0.9607664346694946} 44
# Epoch 44:
# Accuracy train:0.9939302206039429, val:0.9671533107757568
# LOSS train 0.023546765349897462 valid 0.15161845608829155
# Training vs. Validation Loss {'Training': 0.023546765349897462, 'Validation': 0.15161845608829155} 45
# Training vs. Validation accuracy {'Training': 0.9939302206039429, 'Validation': 0.9671533107757568} 45
# Epoch 45:
# Accuracy train:0.9929645657539368, val:0.9671533107757568
# LOSS train 0.02426966949165185 valid 0.13853804868277445
# Training vs. Validation Loss {'Training': 0.02426966949165185, 'Validation': 0.13853804868277445} 46
# Training vs. Validation accuracy {'Training': 0.9929645657539368, 'Validation': 0.9671533107757568} 46
# Epoch 46:
# Accuracy train:0.9943440556526184, val:0.9917883276939392
# LOSS train 0.02995078026919605 valid 0.029888614206748668
# Training vs. Validation Loss {'Training': 0.02995078026919605, 'Validation': 0.029888614206748668} 47
# Training vs. Validation accuracy {'Training': 0.9943440556526184, 'Validation': 0.9917883276939392} 47
# Epoch 47:
# Accuracy train:0.9924127459526062, val:0.9653284549713135
# LOSS train 0.02449279138098783 valid 0.09885447821339613
# Training vs. Validation Loss {'Training': 0.02449279138098783, 'Validation': 0.09885447821339613} 48
# Training vs. Validation accuracy {'Training': 0.9924127459526062, 'Validation': 0.9653284549713135} 48
# Epoch 48:
# Accuracy train:0.993240475654602, val:0.9726277589797974
# LOSS train 0.02638293302440146 valid 0.06986128778331717
# Training vs. Validation Loss {'Training': 0.02638293302440146, 'Validation': 0.06986128778331717} 49
# Training vs. Validation accuracy {'Training': 0.993240475654602, 'Validation': 0.9726277589797974} 49
# Epoch 49:
# Accuracy train:0.993240475654602, val:0.9635036587715149
# LOSS train 0.022646123186939725 valid 0.1399965732492106
# Training vs. Validation Loss {'Training': 0.022646123186939725, 'Validation': 0.1399965732492106} 50
# Training vs. Validation accuracy {'Training': 0.993240475654602, 'Validation': 0.9635036587715149} 50
# Epoch 50:
# Accuracy train:0.9943440556526184, val:0.9689781069755554
# LOSS train 0.0225998732847594 valid 0.06443162249620685
# Training vs. Validation Loss {'Training': 0.0225998732847594, 'Validation': 0.06443162249620685} 51
# Training vs. Validation accuracy {'Training': 0.9943440556526184, 'Validation': 0.9689781069755554} 51
# Epoch 51:
# Accuracy train:0.9940681457519531, val:0.989051103591919
# LOSS train 0.03106464636876698 valid 0.0312028140089225
# Training vs. Validation Loss {'Training': 0.03106464636876698, 'Validation': 0.0312028140089225} 52
# Training vs. Validation accuracy {'Training': 0.9940681457519531, 'Validation': 0.989051103591919} 52
# Epoch 52:
# Accuracy train:0.9937922358512878, val:0.9653284549713135
# LOSS train 0.029590832613853757 valid 0.06159653956319114
# Training vs. Validation Loss {'Training': 0.029590832613853757, 'Validation': 0.06159653956319114} 53
# Training vs. Validation accuracy {'Training': 0.9937922358512878, 'Validation': 0.9653284549713135} 53
# Epoch 53:
# Accuracy train:0.9940681457519531, val:0.9498175382614136
# LOSS train 0.023922933433633452 valid 0.19291485519409754
# Training vs. Validation Loss {'Training': 0.023922933433633452, 'Validation': 0.19291485519409754} 54
# Training vs. Validation accuracy {'Training': 0.9940681457519531, 'Validation': 0.9498175382614136} 54
# Epoch 54:
# Accuracy train:0.9914470911026001, val:0.9534671306610107
# LOSS train 0.02253721267526079 valid 0.17857619237521571
# Training vs. Validation Loss {'Training': 0.02253721267526079, 'Validation': 0.17857619237521571} 55
# Training vs. Validation accuracy {'Training': 0.9914470911026001, 'Validation': 0.9534671306610107} 55
# Epoch 55:
# Accuracy train:0.994895875453949, val:0.9416058659553528
# LOSS train 0.018817183297050087 valid 0.21371108783736095
# Training vs. Validation Loss {'Training': 0.018817183297050087, 'Validation': 0.21371108783736095} 56
# Training vs. Validation accuracy {'Training': 0.994895875453949, 'Validation': 0.9416058659553528} 56
# Epoch 56:
# Accuracy train:0.9940681457519531, val:0.9416058659553528
# LOSS train 0.02060041355003045 valid 0.22929092800687945
# Training vs. Validation Loss {'Training': 0.02060041355003045, 'Validation': 0.22929092800687945} 57
# Training vs. Validation accuracy {'Training': 0.9940681457519531, 'Validation': 0.9416058659553528} 57
# Epoch 57:
# Accuracy train:0.993240475654602, val:0.9625912308692932
# LOSS train 0.016912542656327887 valid 0.11024547741207719
# Training vs. Validation Loss {'Training': 0.016912542656327887, 'Validation': 0.11024547741207719} 58
# Training vs. Validation accuracy {'Training': 0.993240475654602, 'Validation': 0.9625912308692932} 58
# Epoch 58:
# Accuracy train:0.9936543107032776, val:0.970802903175354
# LOSS train 0.016573739135500355 valid 0.08881152891357887
# Training vs. Validation Loss {'Training': 0.016573739135500355, 'Validation': 0.08881152891357887} 59
# Training vs. Validation accuracy {'Training': 0.9936543107032776, 'Validation': 0.970802903175354} 59
# Epoch 59:
# Accuracy train:0.9943440556526184, val:0.959854006767273
# LOSS train 0.020794588483513107 valid 0.17542670707473398
# Training vs. Validation Loss {'Training': 0.020794588483513107, 'Validation': 0.17542670707473398} 60
# Training vs. Validation accuracy {'Training': 0.9943440556526184, 'Validation': 0.959854006767273} 60
# Epoch 60:
# Accuracy train:0.9943440556526184, val:0.9635036587715149
# LOSS train 0.01900148611489535 valid 0.15543195005685118
# Training vs. Validation Loss {'Training': 0.01900148611489535, 'Validation': 0.15543195005685118} 61
# Training vs. Validation accuracy {'Training': 0.9943440556526184, 'Validation': 0.9635036587715149} 61
# Epoch 61:
# Accuracy train:0.994757890701294, val:0.9470803141593933
# LOSS train 0.017353103030632904 valid 0.26057988829690454
# Training vs. Validation Loss {'Training': 0.017353103030632904, 'Validation': 0.26057988829690454} 62
# Training vs. Validation accuracy {'Training': 0.994757890701294, 'Validation': 0.9470803141593933} 62
# Epoch 62:
# Accuracy train:0.994895875453949, val:0.9844890236854553
# LOSS train 0.020775694628025452 valid 0.03609263669149188
# Training vs. Validation Loss {'Training': 0.020775694628025452, 'Validation': 0.03609263669149188} 63
# Training vs. Validation accuracy {'Training': 0.994895875453949, 'Validation': 0.9844890236854553} 63
# Epoch 63:
# Accuracy train:0.9937922358512878, val:0.9808394312858582
# LOSS train 0.021081963278977506 valid 0.06253841721240021
# Training vs. Validation Loss {'Training': 0.021081963278977506, 'Validation': 0.06253841721240021} 64
# Training vs. Validation accuracy {'Training': 0.9937922358512878, 'Validation': 0.9808394312858582} 64
# Epoch 64:
# Accuracy train:0.9937922358512878, val:0.9771897792816162
# LOSS train 0.021719589384252225 valid 0.07010332419939402
# Training vs. Validation Loss {'Training': 0.021719589384252225, 'Validation': 0.07010332419939402} 65
# Training vs. Validation accuracy {'Training': 0.9937922358512878, 'Validation': 0.9771897792816162} 65
# Epoch 65:
# Accuracy train:0.9955856204032898, val:0.9589415788650513
# LOSS train 0.0202009642957569 valid 0.238119308875466
# Training vs. Validation Loss {'Training': 0.0202009642957569, 'Validation': 0.238119308875466} 66
# Training vs. Validation accuracy {'Training': 0.9955856204032898, 'Validation': 0.9589415788650513} 66
# Epoch 66:
# Accuracy train:0.9944819808006287, val:0.944343090057373
# LOSS train 0.01896786733242142 valid 0.20491579281128294
# Training vs. Validation Loss {'Training': 0.01896786733242142, 'Validation': 0.20491579281128294} 67
# Training vs. Validation accuracy {'Training': 0.9944819808006287, 'Validation': 0.944343090057373} 67
# Epoch 67:
# Accuracy train:0.994895875453949, val:0.9644160866737366
# LOSS train 0.019325375087526603 valid 0.1381008924024175
# Training vs. Validation Loss {'Training': 0.019325375087526603, 'Validation': 0.1381008924024175} 68
# Training vs. Validation accuracy {'Training': 0.994895875453949, 'Validation': 0.9644160866737366} 68
# Epoch 68:
# Accuracy train:0.9939302206039429, val:0.959854006767273
# LOSS train 0.017772325113732983 valid 0.1276278470827221
# Training vs. Validation Loss {'Training': 0.017772325113732983, 'Validation': 0.1276278470827221} 69
# Training vs. Validation accuracy {'Training': 0.9939302206039429, 'Validation': 0.959854006767273} 69
# Epoch 69:
# Accuracy train:0.994757890701294, val:0.9644160866737366
# LOSS train 0.01700737031209788 valid 0.10750620276503947
# Training vs. Validation Loss {'Training': 0.01700737031209788, 'Validation': 0.10750620276503947} 70
# Training vs. Validation accuracy {'Training': 0.994757890701294, 'Validation': 0.9644160866737366} 70
# Epoch 70:
# Accuracy train:0.9957235455513, val:0.959854006767273
# LOSS train 0.016384375159379867 valid 0.14445868365618672
# Training vs. Validation Loss {'Training': 0.016384375159379867, 'Validation': 0.14445868365618672} 71
# Training vs. Validation accuracy {'Training': 0.9957235455513, 'Validation': 0.959854006767273} 71
# Epoch 71:
# Accuracy train:0.9962753653526306, val:0.9954379796981812
# LOSS train 0.015416374691754994 valid 0.014170125769024626
# Training vs. Validation Loss {'Training': 0.015416374691754994, 'Validation': 0.014170125769024626} 72
# Training vs. Validation accuracy {'Training': 0.9962753653526306, 'Validation': 0.9954379796981812} 72
# Epoch 72:
# Accuracy train:0.9959994554519653, val:0.9817517995834351
# LOSS train 0.0159713965838239 valid 0.04552375433180603
# Training vs. Validation Loss {'Training': 0.0159713965838239, 'Validation': 0.04552375433180603} 73
# Training vs. Validation accuracy {'Training': 0.9959994554519653, 'Validation': 0.9817517995834351} 73
# Epoch 73:
# Accuracy train:0.9966892004013062, val:0.9972627758979797
# LOSS train 0.017361677228169295 valid 0.014420000011467855
# Training vs. Validation Loss {'Training': 0.017361677228169295, 'Validation': 0.014420000011467855} 74
# Training vs. Validation accuracy {'Training': 0.9966892004013062, 'Validation': 0.9972627758979797} 74
# Epoch 74:
# Accuracy train:0.9958614706993103, val:0.959854006767273
# LOSS train 0.014425376542811256 valid 0.12398423063255072
# Training vs. Validation Loss {'Training': 0.014425376542811256, 'Validation': 0.12398423063255072} 75
# Training vs. Validation accuracy {'Training': 0.9958614706993103, 'Validation': 0.959854006767273} 75
# Epoch 75:
# Accuracy train:0.9950338006019592, val:0.970802903175354
# LOSS train 0.012698642407665649 valid 0.10314973971585252
# Training vs. Validation Loss {'Training': 0.012698642407665649, 'Validation': 0.10314973971585252} 76
# Training vs. Validation accuracy {'Training': 0.9950338006019592, 'Validation': 0.970802903175354} 76
# Epoch 76:
# Accuracy train:0.9958614706993103, val:0.9972627758979797
# LOSS train 0.01266010475476403 valid 0.014077960806381422
# Training vs. Validation Loss {'Training': 0.01266010475476403, 'Validation': 0.014077960806381422} 77
# Training vs. Validation accuracy {'Training': 0.9958614706993103, 'Validation': 0.9972627758979797} 77
# Epoch 77:
# Accuracy train:0.9951717257499695, val:0.9543795585632324
# LOSS train 0.014033942399692023 valid 0.16930286562823307
# Training vs. Validation Loss {'Training': 0.014033942399692023, 'Validation': 0.16930286562823307} 78
# Training vs. Validation accuracy {'Training': 0.9951717257499695, 'Validation': 0.9543795585632324} 78
# Epoch 78:
# Accuracy train:0.9950338006019592, val:0.9635036587715149
# LOSS train 0.017962511295131614 valid 0.1031153894564024
# Training vs. Validation Loss {'Training': 0.017962511295131614, 'Validation': 0.1031153894564024} 79
# Training vs. Validation accuracy {'Training': 0.9950338006019592, 'Validation': 0.9635036587715149} 79
# Epoch 79:
# Accuracy train:0.9954476356506348, val:0.9680656790733337
# LOSS train 0.016969130106000384 valid 0.10066865587041499
# Training vs. Validation Loss {'Training': 0.016969130106000384, 'Validation': 0.10066865587041499} 80
# Training vs. Validation accuracy {'Training': 0.9954476356506348, 'Validation': 0.9680656790733337} 80
# Epoch 80:
# Accuracy train:0.9937922358512878, val:0.9470803141593933
# LOSS train 0.025195354979966927 valid 0.1933127384070394
# Training vs. Validation Loss {'Training': 0.025195354979966927, 'Validation': 0.1933127384070394} 81
# Training vs. Validation accuracy {'Training': 0.9937922358512878, 'Validation': 0.9470803141593933} 81
# Epoch 81:
# Accuracy train:0.9957235455513, val:0.9717153310775757
# LOSS train 0.013632786917166942 valid 0.07458207556703149
# Training vs. Validation Loss {'Training': 0.013632786917166942, 'Validation': 0.07458207556703149} 82
# Training vs. Validation accuracy {'Training': 0.9957235455513, 'Validation': 0.9717153310775757} 82
# Epoch 82:
# Accuracy train:0.9962753653526306, val:0.974452555179596
# LOSS train 0.014220989472200777 valid 0.0665520416770407
# Training vs. Validation Loss {'Training': 0.014220989472200777, 'Validation': 0.0665520416770407} 83
# Training vs. Validation accuracy {'Training': 0.9962753653526306, 'Validation': 0.974452555179596} 83
# Epoch 83:
# Accuracy train:0.9950338006019592, val:0.9671533107757568
# LOSS train 0.02059151988494425 valid 0.10503672100538418
# Training vs. Validation Loss {'Training': 0.02059151988494425, 'Validation': 0.10503672100538418} 84
# Training vs. Validation accuracy {'Training': 0.9950338006019592, 'Validation': 0.9671533107757568} 84
# Epoch 84:
# Accuracy train:0.9957235455513, val:0.9507299065589905
# LOSS train 0.017468394732362127 valid 0.1447310273148514
# Training vs. Validation Loss {'Training': 0.017468394732362127, 'Validation': 0.1447310273148514} 85
# Training vs. Validation accuracy {'Training': 0.9957235455513, 'Validation': 0.9507299065589905} 85
# Epoch 85:
# Accuracy train:0.9961373805999756, val:0.9689781069755554
# LOSS train 0.016151130955572277 valid 0.09602048566750974
# Training vs. Validation Loss {'Training': 0.016151130955572277, 'Validation': 0.09602048566750974} 86
# Training vs. Validation accuracy {'Training': 0.9961373805999756, 'Validation': 0.9689781069755554} 86
# Epoch 86:
# Accuracy train:0.9955856204032898, val:0.9808394312858582
# LOSS train 0.018220633943381293 valid 0.05560616925565804
# Training vs. Validation Loss {'Training': 0.018220633943381293, 'Validation': 0.05560616925565804} 87
# Training vs. Validation accuracy {'Training': 0.9955856204032898, 'Validation': 0.9808394312858582} 87
# Epoch 87:
# Accuracy train:0.9953097105026245, val:0.9571167826652527
# LOSS train 0.017914530798996884 valid 0.11328640020132562
# Training vs. Validation Loss {'Training': 0.017914530798996884, 'Validation': 0.11328640020132562} 88
# Training vs. Validation accuracy {'Training': 0.9953097105026245, 'Validation': 0.9571167826652527} 88
# Epoch 88:
# Accuracy train:0.9955856204032898, val:0.9817517995834351
# LOSS train 0.015355217492110019 valid 0.04906120405774262
# Training vs. Validation Loss {'Training': 0.015355217492110019, 'Validation': 0.04906120405774262} 89
# Training vs. Validation accuracy {'Training': 0.9955856204032898, 'Validation': 0.9817517995834351} 89
# Epoch 89:
# Accuracy train:0.9957235455513, val:0.9580292105674744
# LOSS train 0.014235033087830883 valid 0.1342516128841335
# Training vs. Validation Loss {'Training': 0.014235033087830883, 'Validation': 0.1342516128841335} 90
# Training vs. Validation accuracy {'Training': 0.9957235455513, 'Validation': 0.9580292105674744} 90
# Epoch 90:
# Accuracy train:0.9966892004013062, val:0.9489051103591919
# LOSS train 0.014622720987852637 valid 0.18012363520392813
# Training vs. Validation Loss {'Training': 0.014622720987852637, 'Validation': 0.18012363520392813} 91
# Training vs. Validation accuracy {'Training': 0.9966892004013062, 'Validation': 0.9489051103591919} 91
# Epoch 91:
# Accuracy train:0.9968271255493164, val:0.9616788029670715
# LOSS train 0.012959090888546267 valid 0.0921625000900212
# Training vs. Validation Loss {'Training': 0.012959090888546267, 'Validation': 0.0921625000900212} 92
# Training vs. Validation accuracy {'Training': 0.9968271255493164, 'Validation': 0.9616788029670715} 92
# Epoch 92:
# Accuracy train:0.9966892004013062, val:0.9671533107757568
# LOSS train 0.013082338431638993 valid 0.09134258726029353
# Training vs. Validation Loss {'Training': 0.013082338431638993, 'Validation': 0.09134258726029353} 93
# Training vs. Validation accuracy {'Training': 0.9966892004013062, 'Validation': 0.9671533107757568} 93
# Epoch 93:
# Accuracy train:0.9972410202026367, val:0.8978102207183838
# LOSS train 0.011761293898706464 valid 0.24187437947472742
# Training vs. Validation Loss {'Training': 0.011761293898706464, 'Validation': 0.24187437947472742} 94
# Training vs. Validation accuracy {'Training': 0.9972410202026367, 'Validation': 0.8978102207183838} 94
# Epoch 94:
# Accuracy train:0.9951717257499695, val:0.9808394312858582
# LOSS train 0.020986403627250762 valid 0.04863987924557281
# Training vs. Validation Loss {'Training': 0.020986403627250762, 'Validation': 0.04863987924557281} 95
# Training vs. Validation accuracy {'Training': 0.9951717257499695, 'Validation': 0.9808394312858582} 95
# Epoch 95:
# Accuracy train:0.9959994554519653, val:0.970802903175354
# LOSS train 0.013633485604589293 valid 0.069978612728544
# Training vs. Validation Loss {'Training': 0.013633485604589293, 'Validation': 0.069978612728544} 96
# Training vs. Validation accuracy {'Training': 0.9959994554519653, 'Validation': 0.970802903175354} 96
# Epoch 96:
# Accuracy train:0.9961373805999756, val:0.9516423344612122
# LOSS train 0.014567435499234957 valid 0.17268024838385412
# Training vs. Validation Loss {'Training': 0.014567435499234957, 'Validation': 0.17268024838385412} 97
# Training vs. Validation accuracy {'Training': 0.9961373805999756, 'Validation': 0.9516423344612122} 97
# Epoch 97:
# Accuracy train:0.9965512752532959, val:0.956204354763031
# LOSS train 0.012442503079460489 valid 0.29580141975618435
# Training vs. Validation Loss {'Training': 0.012442503079460489, 'Validation': 0.29580141975618435} 98
# Training vs. Validation accuracy {'Training': 0.9965512752532959, 'Validation': 0.956204354763031} 98
# Epoch 98:
# Accuracy train:0.9966892004013062, val:0.9799270033836365
# LOSS train 0.01015165665204212 valid 0.054695945197467344
# Training vs. Validation Loss {'Training': 0.01015165665204212, 'Validation': 0.054695945197467344} 99
# Training vs. Validation accuracy {'Training': 0.9966892004013062, 'Validation': 0.9799270033836365} 99
# Epoch 99:
# Accuracy train:0.9964132905006409, val:0.9215328693389893
# LOSS train 0.014451853305537632 valid 0.22714952295930704
# Training vs. Validation Loss {'Training': 0.014451853305537632, 'Validation': 0.22714952295930704} 100
# Training vs. Validation accuracy {'Training': 0.9964132905006409, 'Validation': 0.9215328693389893} 100
# Epoch 100:
# Accuracy train:0.9961373805999756, val:0.9899635314941406
# LOSS train 0.015618118764765453 valid 0.029813507429572995
# Training vs. Validation Loss {'Training': 0.015618118764765453, 'Validation': 0.029813507429572995} 101
# Training vs. Validation accuracy {'Training': 0.9961373805999756, 'Validation': 0.9899635314941406} 101
# Epoch 101:
# Accuracy train:0.9971030354499817, val:0.9635036587715149
# LOSS train 0.012507615129504632 valid 0.10264240070346835
# Training vs. Validation Loss {'Training': 0.012507615129504632, 'Validation': 0.10264240070346835} 102
# Training vs. Validation accuracy {'Training': 0.9971030354499817, 'Validation': 0.9635036587715149} 102
# Epoch 102:
# Accuracy train:0.9962753653526306, val:0.930656909942627
# LOSS train 0.014408104408845487 valid 0.2454852545703236
# Training vs. Validation Loss {'Training': 0.014408104408845487, 'Validation': 0.2454852545703236} 103
# Training vs. Validation accuracy {'Training': 0.9962753653526306, 'Validation': 0.930656909942627} 103
# Epoch 103:
# Accuracy train:0.9965512752532959, val:0.9735401272773743
# LOSS train 0.0179773614242979 valid 0.08495452920799354
# Training vs. Validation Loss {'Training': 0.0179773614242979, 'Validation': 0.08495452920799354} 104
# Training vs. Validation accuracy {'Training': 0.9965512752532959, 'Validation': 0.9735401272773743} 104
# Epoch 104:
# Accuracy train:0.9971030354499817, val:0.9507299065589905
# LOSS train 0.006969468612933869 valid 0.2511851006667417
# Training vs. Validation Loss {'Training': 0.006969468612933869, 'Validation': 0.2511851006667417} 105
# Training vs. Validation accuracy {'Training': 0.9971030354499817, 'Validation': 0.9507299065589905} 105
# Epoch 105:
# Accuracy train:0.9965512752532959, val:0.9543795585632324
# LOSS train 0.010735972577854377 valid 0.22792798559546099
# Training vs. Validation Loss {'Training': 0.010735972577854377, 'Validation': 0.22792798559546099} 106
# Training vs. Validation accuracy {'Training': 0.9965512752532959, 'Validation': 0.9543795585632324} 106
# Epoch 106:
# Accuracy train:0.9954476356506348, val:0.9069343209266663
# LOSS train 0.01802034350287983 valid 0.40181274689370317
# Training vs. Validation Loss {'Training': 0.01802034350287983, 'Validation': 0.40181274689370317} 107
# Training vs. Validation accuracy {'Training': 0.9954476356506348, 'Validation': 0.9069343209266663} 107
# stopping at epoch 106, minimum: 0.014077960806381422
# tensor(0.9069)

# %%
list_label = label_dict_from_config_file("hand_gesture.yaml")
DATA_FOLDER_PATH="./data/"
testset = CustomImageDataset(os.path.join(DATA_FOLDER_PATH,"landmark_test.csv"))
test_loader = torch.utils.data.DataLoader(testset,batch_size=20,shuffle=False)

network = NeuralNetwork()
network.load_state_dict(torch.load(best_model_path, weights_only=False))

network.eval()
acc_test = Accuracy(num_classes=len(list_label), task='MULTICLASS')
for i, test_data in enumerate(test_loader):
    test_input, test_label = test_data
    preds = network(test_input)
    acc_test.update(preds, test_label)
print(network.__class__.__name__)
print(f"Accuracy of model:{acc_test.compute().item()}")
print("========================================================================")
# Out:
# NeuralNetwork
# Accuracy of model:0.999018669128418
# ========================================================================
